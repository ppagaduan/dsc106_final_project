# %%
# %pip install altair
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pycountry
import altair as alt

# %%
aids_cases = pd.read_csv('aids_cases_final.csv').dropna()
aids_cases
# Out:
#      Unnamed: 0 Country_Code  Reference_Date             Population Subgroup  \
# 0             0          ABW            1995  Cumulative AIDS cases & deaths
# 1             1          ABW            1996  Cumulative AIDS cases & deaths
# 2            38          AIA            1989  Cumulative AIDS cases & deaths
# 3            50          AIA            1995  Cumulative AIDS cases & deaths
# 4            51          AIA            1995  Cumulative AIDS cases & deaths
# ..          ...          ...             ...                             ...
# 344       18788          WSM            2004  Cumulative AIDS cases & deaths
# 345       18790          WSM            1995  Cumulative AIDS cases & deaths
# 346       19150          ZAF            1987  Cumulative AIDS cases & deaths
# 347       19154          ZAF            1988  Cumulative AIDS cases & deaths
# 348       19158          ZMB            1987  Cumulative AIDS cases & deaths
#
# ...

# %%
codes_and_coordinates = pd.read_csv('countries_codes_and_coordinates.csv')
codes_and_coordinates['Alpha-3 code'] = codes_and_coordinates['Alpha-3 code'].str.replace('"', '')
codes_and_coordinates = codes_and_coordinates.drop(columns=['Alpha-2 code', 'Numeric code'])
codes_and_coordinates['Alpha-3 code'] = codes_and_coordinates['Alpha-3 code'].str.strip()
codes_and_coordinates['Alpha-3 code'].unique()
# Out:
# array(['AFG', 'ALA', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'AIA', 'ATA',
#        'ATG', 'ARG', 'ARM', 'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR',
#        'BGD', 'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL',
#        'BES', 'BIH', 'BWA', 'BVT', 'BRA', 'IOT', 'BRN', 'BGR', 'BFA',
#        'MMR', 'BDI', 'KHM', 'CMR', 'CAN', 'CPV', 'CYM', 'CAF', 'TCD',
#        'CHL', 'CHN', 'CXR', 'CCK', 'COL', 'COM', 'COD', 'COG', 'COK',
#        'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'DNK', 'DJI',
#        'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'ETH',
#        'FLK', 'FRO', 'FJI', 'FIN', 'FRA', 'GUF', 'PYF', 'ATF', 'GAB',
#        'GMB', 'GEO', 'DEU', 'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GLP',
#        'GUM', 'GTM', 'GGY', 'GNB', 'GIN', 'GUY', 'HTI', 'HMD', 'VAT',
#        'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL',
#        'IMN', 'ISR', 'ITA', 'JAM', 'JPN', 'JEY', 'JOR', 'KAZ', 'KEN',
# ...

# %%
with_lat_long = aids_cases.merge(codes_and_coordinates, left_on='Country_Code', right_on='Alpha-3 code')
with_lat_long = with_lat_long.rename(columns = {'Country_y': 'Country'})
with_lat_long['Latitude (average)'] = with_lat_long['Latitude (average)'].str.replace('"', '')
with_lat_long['Longitude (average)'] = with_lat_long['Longitude (average)'].str.replace('"', '')
with_lat_long['Latitude (average)'] = with_lat_long['Latitude (average)'].astype(float)
with_lat_long['Longitude (average)'] = with_lat_long['Longitude (average)'].astype(float)
with_lat_long = with_lat_long.drop(columns=['Unnamed: 0'])
with_lat_long.to_csv('HIV_demographic_data.csv')
